# %%
import pandas as pd

# %%
df=pd.read_csv('../DataSetGFG/nba.csv')
df.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %% [markdown]
# ### Code #1: Check the index at which maximum weight value is present.

# %% [markdown]
# ## boolean indexing

# %%
df[df.Weight==df.Weight.max()].index
# Out:
# Index([405], dtype='int64')

# %% [markdown]
# ## df.series.idxmax()
# in specified series where max value  is present returns its index

# %%
df.Weight.idxmax()
# Out:
# 405

# %% [markdown]
# #### Let’s insert a new row at index 0, having maximum salary and then verify.

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
new_row = pd.DataFrame({'Name':'Geeks', 'Team':'Boston', 'Number':3,
                        'Position':'PG', 'Age':33, 'Height':'6-2',
                        'Weight':189, 'College':'MIT', 'Salary':999999999}
                         , index=[0])
new_row
# Out:
#     Name    Team  Number Position  Age Height  Weight College     Salary
# 0  Geeks  Boston       3       PG   33    6-2     189     MIT  999999999

# %%
df=pd.concat([new_row,df],ignore_index=True)
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0          Geeks          Boston     3.0       PG  33.0    6-2   189.0
# 1  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 2    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College       Salary
# 0                MIT  999999999.0
# 1              Texas    7730337.0
# 2          Marquette    6796117.0
# 3  Boston University          NaN
# 4      Georgia State    1148640.0

# %% [markdown]
# ##### Now, let’s check if the maximum salary is present at index 0 or not.

# %%
df.Salary.idxmax()
# Out:
# 0

# %% [markdown]
# ## minimum index

# %% [markdown]
# #### Check the index at which minimum weight value is present.4

# %%
df=pd.read_csv('../DataSetGFG/nba.csv')
df.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
df.Weight.idxmin()
# Out:
# 152

# %% [markdown]
# ##### Let’s insert a new row at index 0, having minimum salary and then print the minimum salary.

# %%
new_row = pd.DataFrame({'Name':'Geeks', 'Team':'Boston', 'Number':3, 
                        'Position':'PG', 'Age':33, 'Height':'6-2', 
                        'Weight':189, 'College':'MIT', 'Salary':99} 
                         , index=[0])
new_row
# Out:
#     Name    Team  Number Position  Age Height  Weight College  Salary
# 0  Geeks  Boston       3       PG   33    6-2     189     MIT      99

# %%
df=pd.concat([new_row,df],ignore_index=True)
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0            Geeks          Boston     3.0       PG  33.0    6-2   189.0
# 1    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 2      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 454   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 455      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 456   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 457    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 458            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                  MIT       99.0
# ...

# %% [markdown]
# #### let’s check if the minimum salary is present at index 0 or not.

# %%
df.Salary.idxmin()
# Out:
# 0
