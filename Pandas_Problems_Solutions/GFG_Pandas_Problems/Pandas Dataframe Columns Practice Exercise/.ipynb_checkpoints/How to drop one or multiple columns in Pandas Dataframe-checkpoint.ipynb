# %%
Using df.drop() Method
Using iloc[] Method
Using df.ix() method-->deprecated
Using df.loc[] Method
Using Iterative Method
Using Dataframe.pop() Method

# %%
 
# Import pandas package
import pandas as pd
 
# create a dictionary with five fields each
data = {
    'A': ['A1', 'A2', 'A3', 'A4', 'A5'],
    'B': ['B1', 'B2', 'B3', 'B4', 'B5'],
    'C': ['C1', 'C2', 'C3', 'C4', 'C5'],
    'D': ['D1', 'D2', 'D3', 'D4', 'D5'],
    'E': ['E1', 'E2', 'E3', 'E4', 'E5']}
 
# Convert the dictionary into DataFrame
df = pd.DataFrame(data)
 
df
# Out:
#     A   B   C   D   E
# 0  A1  B1  C1  D1  E1
# 1  A2  B2  C2  D2  E2
# 2  A3  B3  C3  D3  E3
# 3  A4  B4  C4  D4  E4
# 4  A5  B5  C5  D5  E5

# %% [markdown]
# ## df.drop()

# %% [markdown]
# ### drop single column
#  In this example we Remove specific single columns as the below code uses Pandas to create a DataFrame from a dictionary and then removes the column ‘A’ using the drop method with axis=1. However, it’s important to note that the original DataFrame (‘df’) remains unchanged unless the inplace=True parameter is used or the result is assigned back to ‘df’.

# %%
df.drop('A',axis=1)#inplace=False
# Out:
#     B   C   D   E
# 0  B1  C1  D1  E1
# 1  B2  C2  D2  E2
# 2  B3  C3  D3  E3
# 3  B4  C4  D4  E4
# 4  B5  C5  D5  E5

# %%
df
# Out:
#     A   B   C   D   E
# 0  A1  B1  C1  D1  E1
# 1  A2  B2  C2  D2  E2
# 2  A3  B3  C3  D3  E3
# 3  A4  B4  C4  D4  E4
# 4  A5  B5  C5  D5  E5

# %% [markdown]
# ### drop multiple columns
# In this example Remove specific multiple columns as the below code uses Pandas to create a DataFrame from a dictionary and then removes columns ‘C’ and ‘D’ using the drop method with axis=1. However, note that the original DataFrame (‘df’) remains unchanged uIn this example Remove columns based on column index as the below code creates a Pandas DataFrame from a dictionary and removes three columns (‘A’, ‘E’, ‘C’) based on their index positions using the `drop` method with `axis=1`. The modified DataFrame is displayed, and the changes are made in place (`inplace=True`)

# %%
df.drop(['A','B'],axis=1)
# Out:
#     C   D   E
# 0  C1  D1  E1
# 1  C2  D2  E2
# 2  C3  D3  E3
# 3  C4  D4  E4
# 4  C5  D5  E5

# %%
df.drop(columns=['A','B'])
# Out:
#     C   D   E
# 0  C1  D1  E1
# 1  C2  D2  E2
# 2  C3  D3  E3
# 3  C4  D4  E4
# 4  C5  D5  E5

# %%
df.columns[[0,1,2]]
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %% [markdown]
# #### In this example Remove columns based on column index as the below code creates a Pandas DataFrame from a dictionary and removes three columns (‘A’, ‘E’, ‘C’) based on their index positions using the `drop` method with `axis=1`. The modified DataFrame is displayed, and the changes are made in place (`inplace=True`).

# %%
df
# Out:
#     A   B   C   D   E
# 0  A1  B1  C1  D1  E1
# 1  A2  B2  C2  D2  E2
# 2  A3  B3  C3  D3  E3
# 3  A4  B4  C4  D4  E4
# 4  A5  B5  C5  D5  E5

# %%
df.drop(df.columns[[0,4,2]],axis=1,inplace=True)

# %%
df
# Out:
#     B   D
# 0  B1  D1
# 1  B2  D2
# 2  B3  D3
# 3  B4  D4
# 4  B5  D5

# %% [markdown]
# ### Dataframe Drop Columns in Pandas using df.iloc[] Method

# %% [markdown]
# #### In this example Delete columns between specific start and end columns as the below code utilizes Pandas to create a DataFrame from a dictionary and then removes all columns between column indices 1 to 3 using the drop method with axis=1. The changes are made in place (inplace=True), and the modified DataFrame is displayed.

# %%
data = {
    'A': ['A1', 'A2', 'A3', 'A4', 'A5'],
    'B': ['B1', 'B2', 'B3', 'B4', 'B5'],
    'C': ['C1', 'C2', 'C3', 'C4', 'C5'],
    'D': ['D1', 'D2', 'D3', 'D4', 'D5'],
    'E': ['E1', 'E2', 'E3', 'E4', 'E5']}
 
# Convert the dictionary into DataFrame
df = pd.DataFrame(data)
df
# Out:
#     A   B   C   D   E
# 0  A1  B1  C1  D1  E1
# 1  A2  B2  C2  D2  E2
# 2  A3  B3  C3  D3  E3
# 3  A4  B4  C4  D4  E4
# 4  A5  B5  C5  D5  E5

# %%
df.iloc[:,1:3]
# Out:
#     B   C
# 0  B1  C1
# 1  B2  C2
# 2  B3  C3
# 3  B4  C4
# 4  B5  C5

# %%
df.drop(columns=df.iloc[:,1:3])
# Out:
#     A   D   E
# 0  A1  D1  E1
# 1  A2  D2  E2
# 2  A3  D3  E3
# 3  A4  D4  E4
# 4  A5  D5  E5

# %% [markdown]
# ### Pandas Drop Columns from Dataframe using df.loc[] Method

# %% [markdown]
# #### Drop columns between specific column names as below code uses Pandas to create a DataFrame from a dictionary and then removes all columns between column names ‘B’ and ‘D’ using the drop method with axis=1. The modified DataFrame is not assigned back to any variable, and the original DataFrame remains unchanged.

# %%
df
# Out:
#     A   B   C   D   E
# 0  A1  B1  C1  D1  E1
# 1  A2  B2  C2  D2  E2
# 2  A3  B3  C3  D3  E3
# 3  A4  B4  C4  D4  E4
# 4  A5  B5  C5  D5  E5

# %%
df.drop(columns=df.loc[:,'B':'D'])
# Out:
#     A   E
# 0  A1  E1
# 1  A2  E2
# 2  A3  E3
# 3  A4  E4
# 4  A5  E5

# %% [markdown]
# ## Pandas Drop Columns from Datafram using Iterative Method

# %%
data = {
    'A': ['A1', 'A2', 'A3', 'A4', 'A5'],
    'B': ['B1', 'B2', 'B3', 'B4', 'B5'],
    'C': ['C1', 'C2', 'C3', 'C4', 'C5'],
    'D': ['D1', 'D2', 'D3', 'D4', 'D5'],
    'E': ['E1', 'E2', 'E3', 'E4', 'E5']}
df=pd.DataFrame(data)
df
# Out:
#     A   B   C   D   E
# 0  A1  B1  C1  D1  E1
# 1  A2  B2  C2  D2  E2
# 2  A3  B3  C3  D3  E3
# 3  A4  B4  C4  D4  E4
# 4  A5  B5  C5  D5  E5

# %% [markdown]
# #### For each column, if the letter ‘A’ is present in the column name, that column is deleted from the DataFrame. The resulting modified DataFrame is displayed.

# %%
for i in range(df.shape[1]):
    if 'A' in df.columns[i]:
        df.drop(columns=df.columns[i],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 2
#       1 for i in range(df.shape[1]):
# ----> 2     if 'A' in df.columns[i]:
#       3         df.drop(columns=df.columns[i],inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:5385, in Index.__getitem__(self, key)
#    5382 if is_integer(key) or is_float(key):
#    5383     # GH#44051 exclude bool, which would return a 2d ndarray
#    5384     key = com.cast_scalar_indexer(key)
# -> 5385     return getitem(key)
#    5387 if isinstance(key, slice):
#    5388     # This case is separated from the conditional above to avoid
#    5389     # pessimization com.is_bool_indexer and ndim checks.
#    5390     return self._getitem_slice(key)
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
df
# Out:
#     B   C   D   E
# 0  B1  C1  D1  E1
# 1  B2  C2  D2  E2
# 2  B3  C3  D3  E3
# 3  B4  C4  D4  E4
# 4  B5  C5  D5  E5

# %%
data = {
    'A': ['A1', 'A2', 'A3', 'A4', 'A5'],
    'B': ['B1', 'B2', 'B3', 'B4', 'B5'],
    'C': ['C1', 'C2', 'C3', 'C4', 'C5'],
    'D': ['D1', 'D2', 'D3', 'D4', 'D5'],
    'E': ['E1', 'E2', 'E3', 'E4', 'E5']}
df=pd.DataFrame(data)
df
# Out:
#     A   B   C   D   E
# 0  A1  B1  C1  D1  E1
# 1  A2  B2  C2  D2  E2
# 2  A3  B3  C3  D3  E3
# 3  A4  B4  C4  D4  E4
# 4  A5  B5  C5  D5  E5

# %%
for col in df.columns:
    if 'A' in col:
        del df[col]

# %%
df
# Out:
#     B   C   D   E
# 0  B1  C1  D1  E1
# 1  B2  C2  D2  E2
# 2  B3  C3  D3  E3
# 3  B4  C4  D4  E4
# 4  B5  C5  D5  E5

# %% [markdown]
# ## df.pop(label)
# return label and delete from dataframe

# %% [markdown]
# #### 3 Drop Column in Pandas using Dataframe.pop() Method

# %%
data = {
    'A': ['A1', 'A2', 'A3', 'A4', 'A5'],
    'B': ['B1', 'B2', 'B3', 'B4', 'B5'],
    'C': ['C1', 'C2', 'C3', 'C4', 'C5'],
    'D': ['D1', 'D2', 'D3', 'D4', 'D5'],
    'E': ['E1', 'E2', 'E3', 'E4', 'E5']}
 
# Convert the dictionary into DataFrame
df = pd.DataFrame(data)
df.pop('B')
df
# Out:
#     A   C   D   E
# 0  A1  C1  D1  E1
# 1  A2  C2  D2  E2
# 2  A3  C3  D3  E3
# 3  A4  C4  D4  E4
# 4  A5  C5  D5  E5

# %%
df.pop(')
# Out:
# 0    B1
# 1    B2
# 2    B3
# 3    B4
# 4    B5
# Name: B, dtype: object
