# %% [markdown]
# # dealing with columns

# %% [markdown]
# ## Column Selection

# %%
  
# Import pandas package
import pandas as pd
 
# Define a dictionary containing employee data
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
 
# Convert the dictionary into DataFrame 
df = pd.DataFrame(data)
df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27      Delhi           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannauj           Phd

# %%
df[['Name','Qualification']]
# Out:
#      Name Qualification
# 0     Jai           Msc
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd

# %%
df[df.columns[0:3]]
# Out:
#      Name  Age    Address
# 0     Jai   27      Delhi
# 1  Princi   24     Kanpur
# 2  Gaurav   22  Allahabad
# 3    Anuj   32    Kannauj

# %%
df.loc[0:1,['Age','Address']]
# Out:
#    Age Address
# 0   27   Delhi
# 1   24  Kanpur

# %%
df.loc[:,['Name','Age']]
# Out:
#      Name  Age
# 0     Jai   27
# 1  Princi   24
# 2  Gaurav   22
# 3    Anuj   32

# %% [markdown]
# ### Column Addition

# %%
data = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc']}

# Convert the dictionary into DataFrame
df = pd.DataFrame(data)
df
# Out:
#      Name  Height Qualification
# 0     Jai     5.1           Msc
# 1  Princi     6.2            MA
# 2  Gaurav     5.1           Msc
# 3    Anuj     5.2           Msc

# %%
address = ['Delhi', 'Bangalore', 'Chennai', 'Patna']
df['Address']=address

# %%
df
# Out:
#      Name  Height Qualification    Address
# 0     Jai     5.1           Msc      Delhi
# 1  Princi     6.2            MA  Bangalore
# 2  Gaurav     5.1           Msc    Chennai
# 3    Anuj     5.2           Msc      Patna

# %%
test=pd.DataFrame({'a':[23,34],'b':[5,7]})
test
# Out:
#     a  b
# 0  23  5
# 1  34  7

# %%
test.assign(c=lambda x:x['a']*2)
# Out:
#     a  b   c
# 0  23  5  46
# 1  34  7  68

# %%
test.insert(1,'s',[44,23])

# %%
test
# Out:
#     a   s  b
# 0  23  44  5
# 1  34  23  7

# %%
test.insert(1,'si',[44,23])

# %%
test
# Out:
#     a  si   s  b
# 0  23  44  44  5
# 1  34  23  23  7

# %%
test.insert(0,'s',[44,23])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6952\167657386.py in ?()
# ----> 1 test.insert(0,'s',[44,23])
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5141                 "'self.flags.allows_duplicate_labels' is False."
#    5142             )
#    5143         if not allow_duplicates and column in self.columns:
#    5144             # Should this be a different kind of error??
# -> 5145             raise ValueError(f"cannot insert {column}, already exists")
#    5146         if not is_integer(loc):
#    5147             raise TypeError("loc must be int")
#    5148         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert s, already exists

# %%
test.insert(0,'s',[44,23],allow_duplicates=True)

# %%
test
# Out:
#     s   a  si   s  b
# 0  44  23  44  44  5
# 1  23  34  23  23  7

# %% [markdown]
# ### Column Deletion

# %%
dd=pd.read_csv('../DataSetGFG/nba.csv')
dd.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
dd.drop(['Team','Weight'],axis=1).head()
# Out:
#             Name  Number Position   Age Height            College     Salary
# 0  Avery Bradley     0.0       PG  25.0    6-2              Texas  7730337.0
# 1    Jae Crowder    99.0       SF  25.0    6-6          Marquette  6796117.0
# 2   John Holland    30.0       SG  27.0    6-5  Boston University        NaN
# 3    R.J. Hunter    28.0       SG  22.0    6-5      Georgia State  1148640.0
# 4  Jonas Jerebko     8.0       PF  29.0   6-10                NaN  5000000.0

# %% [markdown]
# ## dealing with rows

# %%
df=pd.read_csv('../DataSetGFG/nba.csv')
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.loc[0:3,'Name':'Height']
# Out:
#             Name            Team  Number Position   Age Height
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
