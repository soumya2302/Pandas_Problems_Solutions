# %%
import pandas as pd

# %%
df.to_string()
pd.set_option(),pd.reset_option()
with option_context('display.max_rows', 10, 'display.max_columns', 5):
    pass
df.to_markdown()

# %% [markdown]
# ### Method 1: Using to_string()

# %%
iris=pd.read_csv('../../../../Python_tuts_linkInLearn/Advanced_Pandas/Exercise Files/iris.csv')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print(iris.to_string())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %%
print(iris.to_string(max_cols=2))
# Out:
#      sepal_length  ...     species
# 0             5.1  ...      setosa
# 1             4.9  ...      setosa
# 2             4.7  ...      setosa
# 3             4.6  ...      setosa
# 4             5.0  ...      setosa
# 5             5.4  ...      setosa
# 6             4.6  ...      setosa
# 7             5.0  ...      setosa
# 8             4.4  ...      setosa
# 9             4.9  ...      setosa
# 10            5.4  ...      setosa
# 11            4.8  ...      setosa
# 12            4.8  ...      setosa
# 13            4.3  ...      setosa
# 14            5.8  ...      setosa
# 15            5.7  ...      setosa
# 16            5.4  ...      setosa
# 17            5.1  ...      setosa
# 18            5.7  ...      setosa
# 19            5.1  ...      setosa
# 20            5.4  ...      setosa
# 21            5.1  ...      setosa
# 22            4.6  ...      setosa
# 23            5.1  ...      setosa
# 24            4.8  ...      setosa
# 25            5.0  ...      setosa
# ...

# %%
display(iris)#===>iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### Method 3: Using pd.set_option()

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 1)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0    5.1           3.5          1.4           0.2          setosa
# 1    4.9           3.0          1.4           0.2          setosa
# 2    4.7           3.2          1.3           0.2          setosa
# 3    4.6           3.1          1.5           0.2          setosa
# 4    5.0           3.6          1.4           0.2          setosa
# 5    5.4           3.9          1.7           0.4          setosa
# 6    4.6           3.4          1.4           0.3          setosa
# 7    5.0           3.4          1.5           0.2          setosa
# 8    4.4           2.9          1.4           0.2          setosa
# 9    4.9           3.1          1.5           0.1          setosa
# 10   5.4           3.7          1.5           0.2          setosa
# 11   4.8           3.4          1.6           0.2          setosa
# 12   4.8           3.0          1.4           0.1          setosa
# ...

# %% [markdown]
# #### reset_option()-->to reset display setting globally

# %%
pd.reset_option('display.max_columns') # only this setting will be reverted

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0    5.1           3.5          1.4           0.2          setosa
# 1    4.9           3.0          1.4           0.2          setosa
# 2    4.7           3.2          1.3           0.2          setosa
# 3    4.6           3.1          1.5           0.2          setosa
# 4    5.0           3.6          1.4           0.2          setosa
# 5    5.4           3.9          1.7           0.4          setosa
# 6    4.6           3.4          1.4           0.3          setosa
# 7    5.0           3.4          1.5           0.2          setosa
# 8    4.4           2.9          1.4           0.2          setosa
# 9    4.9           3.1          1.5           0.1          setosa
# 10   5.4           3.7          1.5           0.2          setosa
# 11   4.8           3.4          1.6           0.2          setosa
# 12   4.8           3.0          1.4           0.1          setosa
# ...

# %%
pd.reset_option('all') #all 4 settings we set thrrough set_option is reverted globally
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_1808\1613102011.py:1: FutureWarning: data_manager option is deprecated and will be removed in a future version. Only the BlockManager will be available.
#   pd.reset_option('all') #all 4 settings we set thrrough set_option is reverted globally
# C:\Users\soumy\AppData\Local\Temp\ipykernel_1808\1613102011.py:1: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.reset_option('all') #all 4 settings we set thrrough set_option is reverted globally

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Method 2: Using pd.option_context()

# %% [markdown]
# ##### to temporarily change display settings

# %%
with pd.option_context('display.min_rows',None):
    print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Method 4: Using to_markdown()

# %% [markdown]
# #### print dataframe in markdown friendly format

# %%
import tabulate
print(iris.to_markdown())
# Out:
# |     |   sepal_length |   sepal_width |   petal_length |   petal_width | species    |
# |----:|---------------:|--------------:|---------------:|--------------:|:-----------|
# |   0 |            5.1 |           3.5 |            1.4 |           0.2 | setosa     |
# |   1 |            4.9 |           3   |            1.4 |           0.2 | setosa     |
# |   2 |            4.7 |           3.2 |            1.3 |           0.2 | setosa     |
# |   3 |            4.6 |           3.1 |            1.5 |           0.2 | setosa     |
# |   4 |            5   |           3.6 |            1.4 |           0.2 | setosa     |
# |   5 |            5.4 |           3.9 |            1.7 |           0.4 | setosa     |
# |   6 |            4.6 |           3.4 |            1.4 |           0.3 | setosa     |
# |   7 |            5   |           3.4 |            1.5 |           0.2 | setosa     |
# |   8 |            4.4 |           2.9 |            1.4 |           0.2 | setosa     |
# ...
