# %%
import pandas as pd 
  
# Creating the dataframe with dict of lists 
df = pd.DataFrame({'Name': ['Geeks', 'Peter', 'James', 'Jack', 'Lisa'], 
                   'Team': ['Boston', 'Boston', 'Boston', 'Chele', 'Barse'], 
                   'Position': ['PG', 'PG', 'UG', 'PG', 'UG'], 
                   'Number': [3, 4, 7, 11, 5], 
                   'Age': [33, 25, 34, 35, 28], 
                   'Height': ['6-2', '6-4', '5-9', '6-1', '5-8'], 
                   'Weight': [89, 79, 113, 78, 84], 
                   'College': ['MIT', 'MIT', 'MIT', 'Stanford', 'Stanford'], 
                   'Salary': [99999, 99994, 89999, 78889, 87779]}, 
                   index =['ind1', 'ind2', 'ind3', 'ind4', 'ind5']) 
df
# Out:
#        Name    Team Position  Number  Age Height  Weight   College  Salary
# ind1  Geeks  Boston       PG       3   33    6-2      89       MIT   99999
# ind2  Peter  Boston       PG       4   25    6-4      79       MIT   99994
# ind3  James  Boston       UG       7   34    5-9     113       MIT   89999
# ind4   Jack   Chele       PG      11   35    6-1      78  Stanford   78889
# ind5   Lisa   Barse       UG       5   28    5-8      84  Stanford   87779

# %% [markdown]
# #### Check the values PG in column Position

# %%
df.Position=='PG'
# Out:
# ind1     True
# ind2     True
# ind3    False
# ind4     True
# ind5    False
# Name: Position, dtype: bool

# %%
df['Position'].str.contains("PG")
# Out:
# ind1     True
# ind2     True
# ind3    False
# ind4     True
# ind5    False
# Name: Position, dtype: bool

# %% [markdown]
# #### Getting the rows satisfying above condition

# %%
df[df.Position=='PG']
# Out:
#        Name    Team Position  Number  Age Height  Weight   College  Salary
# ind1  Geeks  Boston       PG       3   33    6-2      89       MIT   99999
# ind2  Peter  Boston       PG       4   25    6-4      79       MIT   99994
# ind4   Jack   Chele       PG      11   35    6-1      78  Stanford   78889

# %%
df[df['Position'].str.contains("PG")]
# Out:
#        Name    Team Position  Number  Age Height  Weight   College  Salary
# ind1  Geeks  Boston       PG       3   33    6-2      89       MIT   99999
# ind2  Peter  Boston       PG       4   25    6-4      79       MIT   99994
# ind4   Jack   Chele       PG      11   35    6-1      78  Stanford   78889

# %% [markdown]
# #### Filter all rows where either Team contains ‘Boston’ or College contains ‘MIT’.

# %%
df[(df['Team']=='Boston') | (df['College']=='MIT')]
# Out:
#        Name    Team Position  Number  Age Height  Weight College  Salary
# ind1  Geeks  Boston       PG       3   33    6-2      89     MIT   99999
# ind2  Peter  Boston       PG       4   25    6-4      79     MIT   99994
# ind3  James  Boston       UG       7   34    5-9     113     MIT   89999

# %%
df[(df['Team'].str.contains('Boston')) | (df['College'].str.contains('MIT'))]
# Out:
#        Name    Team Position  Number  Age Height  Weight College  Salary
# ind1  Geeks  Boston       PG       3   33    6-2      89     MIT   99999
# ind2  Peter  Boston       PG       4   25    6-4      79     MIT   99994
# ind3  James  Boston       UG       7   34    5-9     113     MIT   89999

# %% [markdown]
# #### Filter rows checking Team name contains ‘Boston and Position must be PG.

# %%
df=pd.read_csv('../DataSetGFG/nba.csv')
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457                NaN        NaN
#
# [458 rows x 9 columns]

# %%
df[(df['Team'].str.contains('Boston')) & (df['Position'].str.contains('PG'))]
# Out:
#              Name            Team  Number Position   Age Height  Weight  \
# 0   Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 8    Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9    Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 11  Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
#
#            College     Salary
# 0            Texas  7730337.0
# 8       Louisville  1824360.0
# 9   Oklahoma State  3431040.0
# 11      Washington  6912869.0

# %% [markdown]
# #### Filter rows checking Position contains PG and College must contains like UC.

# %%
df[(df['College'].str.contains('UC')) & (df['Position'].str.contains('PG'))]
# Out:
#                   Name                    Team  Number Position   Age Height  \
# 142    Darren Collison        Sacramento Kings     7.0       PG  28.0    6-0
# 264      Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 290       Jrue Holiday    New Orleans Pelicans    11.0       PG  25.0    6-4
# 402        Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 426  Russell Westbrook   Oklahoma City Thunder     0.0       PG  27.0    6-3
#
#      Weight College      Salary
# 142   175.0    UCLA   5013559.0
# 264   180.0    UCLA         NaN
# 290   205.0    UCLA  10595507.0
# 402   189.0    UCLA   2148360.0
# 426   200.0    UCLA  16744218.0
